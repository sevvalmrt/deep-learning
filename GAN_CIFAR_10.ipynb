# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Define a basic transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# Files already downloaded and verified

# %%
# Hyperparameters
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
# Define the generator
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
# Define the discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
# Define the generator and discriminator
# Initialize generator and discriminator
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)
# Loss function
adversarial_loss = nn.BCELoss()
# Optimizers
optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
# Training loop
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
       # Convert list to tensor
        real_images = batch[0].to(device)
        # Adversarial ground truths
        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)
        # Configure input
        real_images = real_images.to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()
        # Sample noise as generator input
        z = torch.randn(real_images.size(0), latent_dim, device=device)
        # Generate a batch of images
        fake_images = generator(z)

        # Measure discriminator's ability
        # to classify real and fake images
        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2
        # Backward pass and optimize
        d_loss.backward()
        optimizer_D.step()

        # -----------------
        #  Train Generator
        # -----------------

        optimizer_G.zero_grad()
        # Generate a batch of images
        gen_images = generator(z)
        # Adversarial loss
        g_loss = adversarial_loss(discriminator(gen_images), valid)
        # Backward pass and optimize
        g_loss.backward()
        optimizer_G.step()
        # ---------------------
        #  Progress Monitoring
        # ---------------------
        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    # Save generated images for every epoch
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.6545 Generator Loss: 0.8008
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.6397 Generator Loss: 0.9844
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.5796 Generator Loss: 1.1839
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.6002 Generator Loss: 1.3927
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.6825 Generator Loss: 1.2790
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6669 Generator Loss: 0.8885
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.7830 Generator Loss: 0.9908
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.6743 Generator Loss: 0.7992
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6597 Generator Loss: 0.9569
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.6128 Generator Loss: 0.9672
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.5075 Generator Loss: 1.2900
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.7692 Generator Loss: 1.2289
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.5848 Generator Loss: 1.1699
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.8758 Generator Loss: 0.5928
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.6240 Generator Loss: 0.8916
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.7071 Generator Loss: 0.8836
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.6389 Generator Loss: 1.0619
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.4379 Generator Loss: 1.2089
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.5657 Generator Loss: 1.1889
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.7217 Generator Loss: 1.0220
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.7265 Generator Loss: 0.8668
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.5579 Generator Loss: 0.8837
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.4320 Generator Loss: 1.2196
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.5508 Generator Loss: 1.3683
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.7731 Generator Loss: 1.5715
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.7111 Generator Loss: 1.1380
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.5199 Generator Loss: 1.1807
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.6558 Generator Loss: 1.0417
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5989 Generator Loss: 1.3416
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.6429 Generator Loss: 0.6791
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5081 Generator Loss: 1.1463
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.6155 Generator Loss: 0.8465
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.5440 Generator Loss: 1.6720
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.5708 Generator Loss: 1.4052
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.4497 Generator Loss: 1.3644
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.3647 Generator Loss: 1.3611
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.8096 Generator Loss: 1.3136
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.5473 Generator Loss: 1.2357
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.5926 Generator Loss: 0.9238
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.5094 Generator Loss: 1.0827
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.5032 Generator Loss: 1.2579
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.5015 Generator Loss: 1.3269
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.8157 Generator Loss: 1.2345
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.5288 Generator Loss: 1.1033
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.8703 Generator Loss: 0.9090
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.4571 Generator Loss: 1.2563
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.4088 Generator Loss: 1.3717
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.4310 Generator Loss: 1.6911
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.5698 Generator Loss: 0.8843
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.6909 Generator Loss: 0.6881
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.4233 Generator Loss: 1.7909
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.3424 Generator Loss: 1.1569
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.8878 Generator Loss: 1.4975
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.6284 Generator Loss: 1.2842
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.3343 Generator Loss: 1.2053
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.4644 Generator Loss: 1.1837
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.4265 Generator Loss: 1.0999
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.6638 Generator Loss: 1.0199
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.4968 Generator Loss: 1.6363
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.3359 Generator Loss: 1.2321
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.7107 Generator Loss: 1.0470
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.7177 Generator Loss: 1.4935
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.4467 Generator Loss: 0.8424
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.4208 Generator Loss: 1.3755
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.4467 Generator Loss: 1.4658
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.7191 Generator Loss: 1.4178
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.6104 Generator Loss: 0.8963
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.5724 Generator Loss: 0.9200
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.6249 Generator Loss: 0.7564
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.4027 Generator Loss: 1.3052
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.6524 Generator Loss: 1.6054
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.5342 Generator Loss: 1.5417
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.4835 Generator Loss: 1.8203
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.5696 Generator Loss: 0.8348
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.5589 Generator Loss: 2.2975
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.4497 Generator Loss: 0.9049
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.5700 Generator Loss: 1.1555
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.6147 Generator Loss: 1.0999
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.5329 Generator Loss: 1.4624
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.3579 Generator Loss: 1.5699
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.5721 Generator Loss: 2.0236
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.4721 Generator Loss: 1.2535
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.6090 Generator Loss: 1.2737
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.7245 Generator Loss: 1.9557
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.4720 Generator Loss: 1.3555
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.4910 Generator Loss: 1.2931
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.6257 Generator Loss: 1.8172
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.4726 Generator Loss: 0.9214
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.6686 Generator Loss: 1.5760
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.7330 Generator Loss: 1.5360
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.5472 Generator Loss: 1.7500
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.5628 Generator Loss: 0.8586
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.8435 Generator Loss: 1.2152
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.3597 Generator Loss: 0.5670
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 1.0375 Generator Loss: 1.2429
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.7049 Generator Loss: 1.4136
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.6711 Generator Loss: 1.0021
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.5516 Generator Loss: 1.7777
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.4402 Generator Loss: 1.4941
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.3723 Generator Loss: 1.3903
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.6441 Generator Loss: 0.7027
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.5581 Generator Loss: 0.7532
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.5523 Generator Loss: 1.1483
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.6055 Generator Loss: 1.4193
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.4757 Generator Loss: 1.8906
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.6104 Generator Loss: 1.1805
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.4581 Generator Loss: 1.5696
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.4702 Generator Loss: 1.3872
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.6436 Generator Loss: 1.1685
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.4834 Generator Loss: 1.1684
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.4651 Generator Loss: 1.3905
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.6526 Generator Loss: 1.5633
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.5435 Generator Loss: 1.4235
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.6800 Generator Loss: 1.2244
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.9254 Generator Loss: 0.6606
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.5639 Generator Loss: 1.4079
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.7342 Generator Loss: 1.1850
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.5771 Generator Loss: 1.0390
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.4828 Generator Loss: 1.1658
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.5446 Generator Loss: 1.3186
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.4079 Generator Loss: 1.5420
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.3799 Generator Loss: 2.1847
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.5312 Generator Loss: 0.9611
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.4948 Generator Loss: 0.9814
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.3640 Generator Loss: 1.6672
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.7511 Generator Loss: 1.1268
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.5747 Generator Loss: 2.3240
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.5692 Generator Loss: 1.4333
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.7355 Generator Loss: 1.9042
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.6531 Generator Loss: 1.7678
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.6709 Generator Loss: 1.0639
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.7415 Generator Loss: 1.0246
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.8759 Generator Loss: 1.6621
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.5248 Generator Loss: 1.0022
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.5258 Generator Loss: 0.9104
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.5929 Generator Loss: 0.8161
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.6301 Generator Loss: 2.2129
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.4414 Generator Loss: 0.8206
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.5443 Generator Loss: 1.0120
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.4539 Generator Loss: 0.8852
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.5929 Generator Loss: 1.0809
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.8172 Generator Loss: 1.7839
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.5943 Generator Loss: 1.0524
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.3889 Generator Loss: 1.0715
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.6833 Generator Loss: 0.7815
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.3585 Generator Loss: 1.2478
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.5752 Generator Loss: 1.3638
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.6094 Generator Loss: 0.7173
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.6132 Generator Loss: 0.4708
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.5166 Generator Loss: 1.7315
